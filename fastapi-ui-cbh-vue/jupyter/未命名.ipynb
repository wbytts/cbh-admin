# %%
print("hello World")
# Out:
# hello World

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,3,4,5,8,9,6,1,3,4,5,2,4])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints
# Out:
# array([1, 3, 4, 5, 8, 9, 6, 1, 3, 4, 5, 2, 4])

# %% [markdown]
# # 标题1
#
# ## 标题2

# %%
print("Hello World")
# Out:
# Hello World

# %%
s = "Hello World"
s = s.upper()
s
# Out:
# 'HELLO WORLD'

# %%
import httpx
import re

url = 'https://zh.javascript.info/ninja-code'

res = httpx.get(url)

# res.text
html = res.text

# html

results = re.findall(r'href="(.*?)"', html)

for item in results:
    print(item)
